# %%
import pandas as pd

# %% [markdown]
# # Combine region + expression/embedding CSVs

# %%
ch_embeddings = pd.read_csv('data/CerebellarHem_embeddings.txt')
ch_expression = pd.read_csv('data/CerebellarHem_expression.txt')
fc_embeddings = pd.read_csv('data/FrontalCortex_embeddings.txt')
fc_expression = pd.read_csv('data/FrontalCortex_expression.txt')
vc_embeddings = pd.read_csv('data/VisualCortex_embeddings.txt')
vc_expression = pd.read_csv('data/VisualCortex_expression.txt')

# %%
ch = pd.merge(ch_embeddings, ch_expression, on="barcode")
fc = pd.merge(fc_embeddings, fc_expression, on="barcode")
vc = pd.merge(vc_embeddings, vc_expression, on="barcode")

# %%
ch['brain_region'] = 'CerebellarHem'
fc['brain_region'] = 'FrontalCortex'
vc['brain_region'] = 'VisualCortex'

# %%
data = pd.concat([ch,fc,vc])

# %% [markdown]
# # Add corresponding cell names and marker genes

# %%
df = pd.read_csv('data/celltypedictionary.txt', sep = ',\'')
# Out:
# C:\Users\lover\anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df = df.rename(columns={"'Clusternum'": "celltype", 
                        "brainregion'": "brain_region", 
                        "cellname'":'cell_name',
                        "markergenes'":'marker_genes'})

# %%
for i, r in df.iterrows():
    df.loc[i, 'brain_region'] = r['brain_region'].strip('\'')
    df.loc[i, 'cell_name'] = r['cell_name'].strip(',').strip('\'')
    if r['marker_genes'] != None:
        df.at[i, 'marker_genes'] = r['marker_genes'].strip('\'').split(',')

# %%
result = pd.merge(data, df, how="outer", on=["brain_region", "celltype"])

# %%
result.to_csv("data/combined.csv")
# Out:
#                       barcode    UMAP_1    UMAP_2  celltype   SLC17A7  \
# 0      Gran_cbm1_TTAATCAGTCGC -1.615211  3.880850         1 -0.432378
# 1      Gran_cbm1_ACAACGACATCC -2.272672  3.821248         1  1.486624
# 2      Gran_cbm1_TATGTCTATATG -1.574344  5.067436         1  1.389476
# 3      Gran_cbm1_TAATGGAAAATA -1.534292  5.076957         1 -0.432378
# 4      Gran_cbm1_CTGGACTACAGC -2.579216  3.784210         1  2.433872
# ...                       ...       ...       ...       ...       ...
# 34894   In8_occ9_TATACCCGTGAA  3.559496  7.151063        17 -0.568610
# 34895  In8_occ11_TGCAATGCCTCA  3.676599  7.974825        17 -0.568610
# 34896  In8_occ11_GAAATCTCTATG  3.748072  7.352611        17 -0.568610
# 34897  In8_occ22_CAGATTCAGTTC  3.693156  7.081617        17 -0.568610
# 34898  In8_occ24_TTATACTCTATT  3.907515  6.740906        17 -0.568610
#
#           SATB2     GRIN1    GRIN2B      GAD1      GAD2  ...    P2RY12  \
# 0     -0.108842 -0.360798 -0.424112 -0.306774 -0.329965  ... -0.141882
# 1     -0.108842 -0.360798 -0.424112 -0.306774 -0.329965  ... -0.141882
# 2     -0.108842 -0.360798 -0.424112 -0.306774 -0.329965  ... -0.141882
# 3     -0.108842 -0.360798 -0.424112 -0.306774 -0.329965  ... -0.141882
# 4     -0.108842 -0.360798 -0.424112 -0.306774 -0.329965  ... -0.141882
# ...         ...       ...       ...       ...       ...  ...       ...
# 34894 -0.475984  1.913866  1.311479  2.932306 -0.315673  ... -0.108569
# 34895 -0.475984  0.889124  0.921432  2.791073 -0.315673  ... -0.108569
# 34896 -0.475984  1.274093  1.804508 -0.378411 -0.315673  ... -0.108569
# 34897 -0.475984 -0.670024 -0.871103 -0.378411 -0.315673  ... -0.108569
# 34898 -0.475984 -0.670024 -0.871103 -0.378411 -0.315673  ... -0.108569
#
#        APBB1IP.1  P2RY12.1      RYR1      RELN      GRM4    RBFOX3  \
# 0      -0.184928 -0.141882 -0.436136  1.192933 -0.554657 -0.945101
# 1      -0.184928 -0.141882 -0.436136  1.690347  1.579240  1.069244
# 2      -0.184928 -0.141882 -0.436136 -0.933421  1.811098  0.586039
# 3      -0.184928 -0.141882 -0.436136  0.620489  0.924131  0.784836
# 4      -0.184928 -0.141882 -0.436136  0.689958 -0.554657  1.373844
# ...          ...       ...       ...       ...       ...       ...
# 34894  -0.142274 -0.108569 -0.197688 -0.250016 -0.125985 -0.668490
# 34895  -0.142274 -0.108569 -0.197688 -0.250016 -0.125985 -0.668490
# 34896  -0.142274 -0.108569 -0.197688 -0.250016 -0.125985 -0.668490
# 34897  -0.142274 -0.108569 -0.197688 -0.250016 -0.125985  1.765473
# 34898  -0.142274 -0.108569 -0.197688 -0.250016 -0.125985 -0.668490
#
#         brain_region          cell_name          marker_genes
# 0      CerebellarHem       Granule Cell  [RELN, GRM4, RBFOX3]
# 1      CerebellarHem       Granule Cell  [RELN, GRM4, RBFOX3]
# 2      CerebellarHem       Granule Cell  [RELN, GRM4, RBFOX3]
# 3      CerebellarHem       Granule Cell  [RELN, GRM4, RBFOX3]
# 4      CerebellarHem       Granule Cell  [RELN, GRM4, RBFOX3]
# ...              ...                ...                   ...
# 34894   VisualCortex  Inhibitory Neuron   [GAD1, GAD2, SLCA1]
# 34895   VisualCortex  Inhibitory Neuron   [GAD1, GAD2, SLCA1]
# 34896   VisualCortex  Inhibitory Neuron   [GAD1, GAD2, SLCA1]
# 34897   VisualCortex  Inhibitory Neuron   [GAD1, GAD2, SLCA1]
# 34898   VisualCortex  Inhibitory Neuron   [GAD1, GAD2, SLCA1]
#
# [34899 rows x 38 columns]
